# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision.datasets import CIFAR10

# %%
# Create Dataset and Dataloader
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# image => scale(0, 1) ==> normalize ==> range(-1, 1)
transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5)) ## () () standard deviation and mean
])

trainset = CIFAR10(root='../../../Dataset', train=True, download=True, transform=transforms)
testset = CIFAR10(root='../../../Dataset', train=False, download=True, transform=transforms)
# Out:
# 100.0%

# %%
trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
testloader = DataLoader(testset, batch_size=64)

# %% [markdown]
# ## Build The CNN

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layers = nn.Sequential(
            nn.conv2D(3, , kernel_size=3, padding=1),
            nn.RelU(),
            nn.MaxPool2D(2, 2) # kernel size = 2, stride = 2
        )
